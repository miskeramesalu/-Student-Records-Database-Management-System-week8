# %% [markdown]
# <a href="https://colab.research.google.com/github/miskeramesalu/-Student-Records-Database-Management-System-week8/blob/main/HuggingFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

#Load GPT2 Models from hugging Face
generator = pipeline("text-generation", model="gpt2")
print("This is GPT2 Models powered by JsMummie Herself")

while True:
  prompt = input("You: ").strip()
  if prompt.lower() in {"exit", "quit"}:
    print("GoodBye!, Remember to code on daily basis")
    break

  #Generate the text/output
  output = generator(prompt, max_new_tokens=1000, temperature=0.7)
  print("\nAI: ", output[0]["generated_text"], "\n")
# Out:
# Device set to use cpu
# This is GPT2 Models powered by JsMummie Herself
# You: Hello
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
